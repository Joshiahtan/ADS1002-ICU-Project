# %%
# import relevant libraries and modules

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv("Preprocessed ICU data.csv")
df = df[~np.isclose(df["Gender"].round(8), 0.56192144,atol=1e-8)]
gen = df.iloc[:,:7]
mean1 = df.iloc[:,7:44]
min1 = df.iloc[:,44:81]
max1 = df.iloc[:,81:118]
mean2 = df.iloc[:,118:155]
min2 = df.iloc[:,155:192]
max2 = df.iloc[:,192:229]
outcome = df.iloc[:,229:]

# %%
gen
# Out:
#       RecordID  Age  Gender      Height  ICUType2  ICUType3  ICUType4
# 0       132543   68     1.0  180.300000         0         1         0
# 1       132545   88     0.0  169.787227         0         1         0
# 2       132547   64     1.0  180.300000         0         0         0
# 3       132551   78     0.0  162.600000         0         1         0
# 4       132554   64     0.0  169.787227         0         1         0
# ...        ...  ...     ...         ...       ...       ...       ...
# 1469    142661   89     1.0  177.800000         0         0         1
# 1470    142662   86     1.0  162.600000         0         1         0
# 1471    142664   51     0.0  169.787227         0         0         1
# 1472    142665   70     0.0  169.787227         0         0         1
# 1473    142671   37     1.0  169.787227         0         1         0
#
# [1472 rows x 7 columns]

# %%
X = df.drop(["In.hospital_death", "RecordID"], axis = 1)
y = df["In.hospital_death"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 42)

# %%
model = RandomForestClassifier(random_state=42)
rfe = RFE(estimator=model, n_features_to_select=10)

# %%
rfe.fit(X_train,y_train)
ranking=rfe.ranking_
selected_features = X.columns[rfe.support_]

# %%
print("Selected Features: ", selected_features)
# Out:
# Selected Features:  Index(['Mean_HR.x', 'Max_HR.x', 'Mean_GCS.y', 'Mean_NISysABP.y',
#        'Mean_Urine.y', 'Mean_BUN.y', 'Min_Weight.y', 'Min_Lactate.y',
#        'Max_GCS.y', 'Max_WBC.y'],
#       dtype='object')

# %%
X_train_selected = rfe.transform(X_train)
X_test_selected = rfe.transform(X_test)

# %%
model.fit(X_train_selected,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=model.predict(X_test_selected)
accuracy=accuracy_score(y_test,y_pred)

# %%
print("Model accuracy with Selected Features:", accuracy)
# Out:
# Model accuracy with Selected Features: 0.7171945701357466

# %%
X2 = mean1
X_train, X_test, y_train, y_test = train_test_split(X2,y,test_size = 0.3, random_state = 42)
rfe2 = RFE(estimator=model, n_features_to_select=5)
rfe2.fit(X_train,y_train)
ranking=rfe2.ranking_
selected_features = X2.columns[rfe2.support_]

# %%
print("Selected Features: ", selected_features)
X_train_selected = rfe2.transform(X_train)
X_test_selected = rfe2.transform(X_test)
# Out:
# Selected Features:  Index(['Mean_GCS.x', 'Mean_HR.x', 'Mean_Urine.x', 'Mean_Platelets.x',
#        'Mean_PaCO2.x'],
#       dtype='object')

# %%
model.fit(X_train_selected,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=model.predict(X_test_selected)
accuracy=accuracy_score(y_test,y_pred)

# %%
print("Model accuracy with Selected Features:", accuracy)
# Out:
# Model accuracy with Selected Features: 0.6606334841628959

# %%
def do_rfe(X, y, n_features_to_select):
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 42)
    model = RandomForestClassifier(random_state=42)
    rfe = RFE(estimator=model, n_features_to_select=n_features_to_select)
    rfe.fit(X_train,y_train)
    ranking=rfe.ranking_
    selected_features = X.columns[rfe.support_]
    X_train_selected = rfe.transform(X_train)
    X_test_selected = rfe.transform(X_test)
    model.fit(X_train_selected,y_train)
    y_pred=model.predict(X_test_selected)
    accuracy=accuracy_score(y_test,y_pred)
    importance = model.feature_importances_

    results = pd.DataFrame({
        'Feature': X.columns,
        'Ranking': ranking,
        'Importance': importance})
        
    # print("Selected Features: ", selected_features)
    # print(X.columns)
    # print(ranking)
    # print("Model accuracy with Selected Features:", accuracy)

    return results

# %%
def do_rfe(X, y, n_features_to_select):
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.3, random_state = 42)
    model = RandomForestClassifier(random_state=42)
    rfe = RFE(estimator=model, n_features_to_select=n_features_to_select)
    rfe.fit(X_train,y_train)
    ranking=rfe.ranking_
    selected_features = X.columns[rfe.support_]
    X_train_selected = rfe.transform(X_train)
    X_test_selected = rfe.transform(X_test)
    model.fit(X_train_selected,y_train)
    y_pred=model.predict(X_test_selected)
    accuracy=accuracy_score(y_test,y_pred)
    # importance = model.feature_importances_

    results = pd.DataFrame({
        'Feature': X.columns,
        'Ranking': ranking})
        
    # print("Selected Features: ", selected_features)
    # print(X.columns)
    # print(ranking)
    # print("Model accuracy with Selected Features:", accuracy)

    return results

# %%
min1_r = do_rfe(min1, y, 2)

# %%
max1_r = do_rfe(max1,y,2)

# %%
mean1_r = do_rfe(mean1,y,2)

# %%
mean2_r = do_rfe(mean2,y,2)

# %%
max2_r = do_rfe(max2,y,2)

# %%
min2_r = do_rfe(min2,y,2)

# %%
gen_r = do_rfe(gen.drop("RecordID", axis =1),y,3)

# %%
mean1_r = mean1_r.sort_values(by="Ranking", ascending=True)

# %%
max1_r = max1_r.sort_values(by="Ranking", ascending=True)

# %%
min1_r = min1_r.sort_values(by="Ranking", ascending=True)
mean2_r = mean2_r.sort_values(by="Ranking", ascending=True)
max2_r = max2_r.sort_values(by="Ranking", ascending=True)
min2_r = min2_r.sort_values(by="Ranking", ascending=True)

# %%
all_ranks2 = pd.concat([mean1_r,max1_r,min1_r,mean2_r,max2_r,min2_r], axis =1)

# %%
all_ranks = pd.concat([mean1_r,max1_r,min1_r,mean2_r,max2_r,min2_r], axis =1)

# %%
all_ranks
# Out:
#                Feature  Ranking            Feature  Ranking  \
# 8         Mean_Urine.x        1        Max_Urine.x        5
# 2            Mean_HR.x        1           Max_HR.x        3
# 15    Mean_Platelets.x        2    Max_Platelets.x        1
# 1           Mean_GCS.x        3          Max_GCS.x        9
# 20        Mean_PaCO2.x        4        Max_PaCO2.x        6
# 13          Mean_GCT.x        5          Max_GCT.x        4
# 7          Mean_Temp.x        6         Max_Temp.x       14
# 26       Mean_SysABP.x        7       Max_SysABP.x       11
# 9           Mean_BUN.x        8          Max_BUN.x       10
# 12         Mean_HCO3.x        9         Max_HCO3.x       16
# 11      Mean_Glucose.x       10      Max_Glucose.x        1
# 21         Mean_PaO2.x       11         Max_PaO2.x       13
# 23         Mean_FiO2.x       12         Max_FiO2.x       32
# 5      Mean_NISysABP.x       13     Max_NISysABP.x        7
# 0        Mean_Weight.x       14       Max_Weight.x        8
# 19           Mean_pH.x       15           Max_pH.x       21
# 33      Mean_Lactate.x       16      Max_Lactate.x       12
# 18          Mean_WBC.x       17          Max_WBC.x        2
# 28      Mean_Albumin.x       18      Max_Albumax.x       19
# 3     Mean_NIDiasABP.x       19    Max_NIDiasABP.x       25
# 17           Mean_Na.x       20           Max_Na.x       17
# 31          Mean_AST.x       21          Max_AST.x       26
# 4         Mean_NIMAP.x       22        Max_NIMAP.x       18
# 10   Mean_Creatinine.x       23   Max_Creatinine.x       20
# 32    Mean_Bilirubin.x       24    Max_Bilirubin.x       15
# 14           Mean_Mg.x       25           Max_Mg.x       22
# 16            Mean_K.x       26            Max_K.x       23
# 30          Mean_ALT.x       27          Max_ALT.x       27
# 22      Mean_DiasABP.x       28      Max_DiasABP.x       28
# 24          Mean_MAP.x       29          Max_MAP.x       24
# 6      Mean_RespRate.x       30     Max_RespRate.x       29
# 27         Mean_SaO2.x       31         Max_SaO2.x       33
# 29          Mean_ALP.x       32          Max_ALP.x       30
# 36    Mean_TroponinT.x       33    Max_TroponinT.x       31
# 35    Mean_TroponinI.x       34    Max_TroponinI.x       34
# 34  Mean_Cholesterol.x       35  Max_Cholesterol.x       35
# 25     Mean_MechVent.x       36     Max_MechVent.x       36
#
#               Feature  Ranking             Feature  Ranking  \
# 8         Min_Urine.x       24        Mean_Urine.y        1
# 2            Min_HR.x       10           Mean_HR.y        4
# 15    Min_Platelets.x        1    Mean_Platelets.y       11
# 1           Min_GCS.x       21          Mean_GCS.y        1
# 20        Min_PaCO2.x       11        Mean_PaCO2.y       10
# 13          Min_GCT.x        9          Mean_GCT.y        7
# 7          Min_Temp.x        8         Mean_Temp.y        9
# 26       Min_SysABP.x       29       Mean_SysABP.y       13
# 9           Min_BUN.x        5          Mean_BUN.y        5
# 12         Min_HCO3.x       12         Mean_HCO3.y       17
# 11      Min_Glucose.x        4      Mean_Glucose.y        6
# 21         Min_PaO2.x       13         Mean_PaO2.y       12
# 23         Min_FiO2.x       27         Mean_FiO2.y       25
# 5      Min_NISysABP.x       15     Mean_NISysABP.y        3
# 0        Min_Weight.x        1       Mean_Weight.y       14
# 19           Min_pH.x        3           Mean_pH.y       22
# 33      Min_Lactate.x        7      Mean_Lactate.y        8
# 18          Min_WBC.x        2          Mean_WBC.y        2
# 28      Min_Albumin.x       18      Mean_Albumin.y       28
# 3     Min_NIDiasABP.x       19    Mean_NIDiasABP.y       19
# 17           Min_Na.x       22           Mean_Na.y       16
# 31          Min_AST.x       20          Mean_AST.y       27
# 4         Min_NIMAP.x        6        Mean_NIMAP.y       18
# 10   Min_Creatinine.x       16   Mean_Creatinine.y       20
# 32    Min_Bilirubin.x       14    Mean_Bilirubin.y       15
# 14           Min_Mg.x       25           Mean_Mg.y       21
# 16            Min_K.x       23            Mean_K.y       23
# 30          Min_ALT.x       26          Mean_ALT.y       24
# 22      Min_DiasABP.x       28      Mean_DiasABP.y       29
# 24          Min_MAP.x       17          Mean_MAP.y       26
# 6      Min_RespRate.x       31     Mean_RespRate.y       31
# 27         Min_SaO2.x       33         Mean_SaO2.y       33
# 29          Min_ALP.x       30          Mean_ALP.y       32
# 36    Min_TroponinT.x       32    Mean_TroponinT.y       30
# 35    Min_TroponinI.x       34    Mean_TroponinI.y       34
# 34  Min_Cholesterol.x       35  Mean_Cholesterol.y       35
# 25     Min_MechVent.x       36     Mean_MechVent.y       36
#
#               Feature  Ranking            Feature  Ranking
# 8         Max_Urine.y        3        Min_Urine.y       18
# 2            Max_HR.y        5           Min_HR.y        8
# 15    Max_Platelets.y        6    Min_Platelets.y        1
# 1           Max_GCS.y        4          Min_GCS.y        4
# 20        Max_PaCO2.y       15        Min_PaCO2.y       14
# 13          Max_GCT.y        1          Min_GCT.y        3
# 7          Max_Temp.y       19         Min_Temp.y        9
# 26       Max_SysABP.y        9       Min_SysABP.y       16
# 9           Max_BUN.y       10          Min_BUN.y        5
# 12         Max_HCO3.y       22         Min_HCO3.y       10
# 11      Max_Glucose.y        2      Min_Glucose.y        6
# 21         Max_PaO2.y        8         Min_PaO2.y       12
# 23         Max_FiO2.y       30         Min_FiO2.y       30
# 5      Max_NISysABP.y        7     Min_NISysABP.y       15
# 0        Max_Weight.y       11       Min_Weight.y        2
# 19           Max_pH.y       24           Min_pH.y       24
# 33      Max_Lactate.y       12      Min_Lactate.y        7
# 18          Max_WBC.y        1          Min_WBC.y        1
# 28      Max_Albumax.y       26      Min_Albumin.y       23
# 3     Max_NIDiasABP.y       18    Min_NIDiasABP.y       25
# 17           Max_Na.y       16           Min_Na.y       17
# 31          Max_AST.y       20          Min_AST.y       20
# 4         Max_NIMAP.y       13        Min_NIMAP.y       11
# 10   Max_Creatinine.y       17   Min_Creatinine.y       22
# 32    Max_Bilirubin.y       14    Min_Bilirubin.y       13
# 14           Max_Mg.y       21           Min_Mg.y       19
# 16            Max_K.y       23            Min_K.y       21
# 30          Max_ALT.y       27          Min_ALT.y       27
# 22      Max_DiasABP.y       25      Min_DiasABP.y       28
# 24          Max_MAP.y       28          Min_MAP.y       26
# 6      Max_RespRate.y       32     Min_RespRate.y       33
# 27         Max_SaO2.y       33         Min_SaO2.y       32
# 29          Max_ALP.y       29          Min_ALP.y       29
# 36    Max_TroponinT.y       31    Min_TroponinT.y       31
# 35    Max_TroponinI.y       34    Min_TroponinI.y       34
# 34  Max_Cholesterol.y       35  Min_Cholesterol.y       35
# 25     Max_MechVent.y       36     Min_MechVent.y       36

# %%
all_ranks2
# Out:
#                Feature  Ranking            Feature  Ranking  \
# 8         Mean_Urine.x        1        Max_Urine.x        5
# 2            Mean_HR.x        1           Max_HR.x        3
# 15    Mean_Platelets.x        2    Max_Platelets.x        1
# 1           Mean_GCS.x        3          Max_GCS.x        9
# 20        Mean_PaCO2.x        4        Max_PaCO2.x        6
# 13          Mean_GCT.x        5          Max_GCT.x        4
# 7          Mean_Temp.x        6         Max_Temp.x       14
# 26       Mean_SysABP.x        7       Max_SysABP.x       11
# 9           Mean_BUN.x        8          Max_BUN.x       10
# 12         Mean_HCO3.x        9         Max_HCO3.x       16
# 11      Mean_Glucose.x       10      Max_Glucose.x        1
# 21         Mean_PaO2.x       11         Max_PaO2.x       13
# 23         Mean_FiO2.x       12         Max_FiO2.x       32
# 5      Mean_NISysABP.x       13     Max_NISysABP.x        7
# 0        Mean_Weight.x       14       Max_Weight.x        8
# 19           Mean_pH.x       15           Max_pH.x       21
# 33      Mean_Lactate.x       16      Max_Lactate.x       12
# 18          Mean_WBC.x       17          Max_WBC.x        2
# 28      Mean_Albumin.x       18      Max_Albumax.x       19
# 3     Mean_NIDiasABP.x       19    Max_NIDiasABP.x       25
# 17           Mean_Na.x       20           Max_Na.x       17
# 31          Mean_AST.x       21          Max_AST.x       26
# 4         Mean_NIMAP.x       22        Max_NIMAP.x       18
# 10   Mean_Creatinine.x       23   Max_Creatinine.x       20
# 32    Mean_Bilirubin.x       24    Max_Bilirubin.x       15
# 14           Mean_Mg.x       25           Max_Mg.x       22
# 16            Mean_K.x       26            Max_K.x       23
# 30          Mean_ALT.x       27          Max_ALT.x       27
# 22      Mean_DiasABP.x       28      Max_DiasABP.x       28
# 24          Mean_MAP.x       29          Max_MAP.x       24
# 6      Mean_RespRate.x       30     Max_RespRate.x       29
# 27         Mean_SaO2.x       31         Max_SaO2.x       33
# 29          Mean_ALP.x       32          Max_ALP.x       30
# 36    Mean_TroponinT.x       33    Max_TroponinT.x       31
# 35    Mean_TroponinI.x       34    Max_TroponinI.x       34
# 34  Mean_Cholesterol.x       35  Max_Cholesterol.x       35
# 25     Mean_MechVent.x       36     Max_MechVent.x       36
#
#               Feature  Ranking             Feature  Ranking  \
# 8         Min_Urine.x       24        Mean_Urine.y        1
# 2            Min_HR.x       10           Mean_HR.y        4
# 15    Min_Platelets.x        1    Mean_Platelets.y       11
# 1           Min_GCS.x       21          Mean_GCS.y        1
# 20        Min_PaCO2.x       11        Mean_PaCO2.y       10
# 13          Min_GCT.x        9          Mean_GCT.y        7
# 7          Min_Temp.x        8         Mean_Temp.y        9
# 26       Min_SysABP.x       29       Mean_SysABP.y       13
# 9           Min_BUN.x        5          Mean_BUN.y        5
# 12         Min_HCO3.x       12         Mean_HCO3.y       17
# 11      Min_Glucose.x        4      Mean_Glucose.y        6
# 21         Min_PaO2.x       13         Mean_PaO2.y       12
# 23         Min_FiO2.x       27         Mean_FiO2.y       25
# 5      Min_NISysABP.x       15     Mean_NISysABP.y        3
# 0        Min_Weight.x        1       Mean_Weight.y       14
# 19           Min_pH.x        3           Mean_pH.y       22
# 33      Min_Lactate.x        7      Mean_Lactate.y        8
# 18          Min_WBC.x        2          Mean_WBC.y        2
# 28      Min_Albumin.x       18      Mean_Albumin.y       28
# 3     Min_NIDiasABP.x       19    Mean_NIDiasABP.y       19
# 17           Min_Na.x       22           Mean_Na.y       16
# 31          Min_AST.x       20          Mean_AST.y       27
# 4         Min_NIMAP.x        6        Mean_NIMAP.y       18
# 10   Min_Creatinine.x       16   Mean_Creatinine.y       20
# 32    Min_Bilirubin.x       14    Mean_Bilirubin.y       15
# 14           Min_Mg.x       25           Mean_Mg.y       21
# 16            Min_K.x       23            Mean_K.y       23
# 30          Min_ALT.x       26          Mean_ALT.y       24
# 22      Min_DiasABP.x       28      Mean_DiasABP.y       29
# 24          Min_MAP.x       17          Mean_MAP.y       26
# 6      Min_RespRate.x       31     Mean_RespRate.y       31
# 27         Min_SaO2.x       33         Mean_SaO2.y       33
# 29          Min_ALP.x       30          Mean_ALP.y       32
# 36    Min_TroponinT.x       32    Mean_TroponinT.y       30
# 35    Min_TroponinI.x       34    Mean_TroponinI.y       34
# 34  Min_Cholesterol.x       35  Mean_Cholesterol.y       35
# 25     Min_MechVent.x       36     Mean_MechVent.y       36
#
#               Feature  Ranking            Feature  Ranking
# 8         Max_Urine.y        3        Min_Urine.y       18
# 2            Max_HR.y        5           Min_HR.y        8
# 15    Max_Platelets.y        6    Min_Platelets.y        1
# 1           Max_GCS.y        4          Min_GCS.y        4
# 20        Max_PaCO2.y       15        Min_PaCO2.y       14
# 13          Max_GCT.y        1          Min_GCT.y        3
# 7          Max_Temp.y       19         Min_Temp.y        9
# 26       Max_SysABP.y        9       Min_SysABP.y       16
# 9           Max_BUN.y       10          Min_BUN.y        5
# 12         Max_HCO3.y       22         Min_HCO3.y       10
# 11      Max_Glucose.y        2      Min_Glucose.y        6
# 21         Max_PaO2.y        8         Min_PaO2.y       12
# 23         Max_FiO2.y       30         Min_FiO2.y       30
# 5      Max_NISysABP.y        7     Min_NISysABP.y       15
# 0        Max_Weight.y       11       Min_Weight.y        2
# 19           Max_pH.y       24           Min_pH.y       24
# 33      Max_Lactate.y       12      Min_Lactate.y        7
# 18          Max_WBC.y        1          Min_WBC.y        1
# 28      Max_Albumax.y       26      Min_Albumin.y       23
# 3     Max_NIDiasABP.y       18    Min_NIDiasABP.y       25
# 17           Max_Na.y       16           Min_Na.y       17
# 31          Max_AST.y       20          Min_AST.y       20
# 4         Max_NIMAP.y       13        Min_NIMAP.y       11
# 10   Max_Creatinine.y       17   Min_Creatinine.y       22
# 32    Max_Bilirubin.y       14    Min_Bilirubin.y       13
# 14           Max_Mg.y       21           Min_Mg.y       19
# 16            Max_K.y       23            Min_K.y       21
# 30          Max_ALT.y       27          Min_ALT.y       27
# 22      Max_DiasABP.y       25      Min_DiasABP.y       28
# 24          Max_MAP.y       28          Min_MAP.y       26
# 6      Max_RespRate.y       32     Min_RespRate.y       33
# 27         Max_SaO2.y       33         Min_SaO2.y       32
# 29          Max_ALP.y       29          Min_ALP.y       29
# 36    Max_TroponinT.y       31    Min_TroponinT.y       31
# 35    Max_TroponinI.y       34    Min_TroponinI.y       34
# 34  Max_Cholesterol.y       35  Min_Cholesterol.y       35
# 25     Max_MechVent.y       36     Min_MechVent.y       36

# %%
all_ranks2['Row Sum'] = all_ranks2.select_dtypes(include='number').sum(axis=1)

# %%
all_ranks2.sort_values(by="Row Sum", ascending=True)
# Out:
#                Feature  Ranking            Feature  Ranking  \
# 15    Mean_Platelets.x        2    Max_Platelets.x        1
# 18          Mean_WBC.x       17          Max_WBC.x        2
# 11      Mean_Glucose.x       10      Max_Glucose.x        1
# 13          Mean_GCT.x        5          Max_GCT.x        4
# 2            Mean_HR.x        1           Max_HR.x        3
# 1           Mean_GCS.x        3          Max_GCS.x        9
# 9           Mean_BUN.x        8          Max_BUN.x       10
# 0        Mean_Weight.x       14       Max_Weight.x        8
# 8         Mean_Urine.x        1        Max_Urine.x        5
# 5      Mean_NISysABP.x       13     Max_NISysABP.x        7
# 20        Mean_PaCO2.x        4        Max_PaCO2.x        6
# 33      Mean_Lactate.x       16      Max_Lactate.x       12
# 7          Mean_Temp.x        6         Max_Temp.x       14
# 21         Mean_PaO2.x       11         Max_PaO2.x       13
# 26       Mean_SysABP.x        7       Max_SysABP.x       11
# 12         Mean_HCO3.x        9         Max_HCO3.x       16
# 4         Mean_NIMAP.x       22        Max_NIMAP.x       18
# 32    Mean_Bilirubin.x       24    Max_Bilirubin.x       15
# 17           Mean_Na.x       20           Max_Na.x       17
# 19           Mean_pH.x       15           Max_pH.x       21
# 10   Mean_Creatinine.x       23   Max_Creatinine.x       20
# 3     Mean_NIDiasABP.x       19    Max_NIDiasABP.x       25
# 28      Mean_Albumin.x       18      Max_Albumax.x       19
# 14           Mean_Mg.x       25           Max_Mg.x       22
# 31          Mean_AST.x       21          Max_AST.x       26
# 16            Mean_K.x       26            Max_K.x       23
# 24          Mean_MAP.x       29          Max_MAP.x       24
# 23         Mean_FiO2.x       12         Max_FiO2.x       32
# 30          Mean_ALT.x       27          Max_ALT.x       27
# 22      Mean_DiasABP.x       28      Max_DiasABP.x       28
# 29          Mean_ALP.x       32          Max_ALP.x       30
# 6      Mean_RespRate.x       30     Max_RespRate.x       29
# 36    Mean_TroponinT.x       33    Max_TroponinT.x       31
# 27         Mean_SaO2.x       31         Max_SaO2.x       33
# 35    Mean_TroponinI.x       34    Max_TroponinI.x       34
# 34  Mean_Cholesterol.x       35  Max_Cholesterol.x       35
# 25     Mean_MechVent.x       36     Max_MechVent.x       36
#
#               Feature  Ranking             Feature  Ranking  \
# 15    Min_Platelets.x        1    Mean_Platelets.y       11
# 18          Min_WBC.x        2          Mean_WBC.y        2
# 11      Min_Glucose.x        4      Mean_Glucose.y        6
# 13          Min_GCT.x        9          Mean_GCT.y        7
# 2            Min_HR.x       10           Mean_HR.y        4
# 1           Min_GCS.x       21          Mean_GCS.y        1
# 9           Min_BUN.x        5          Mean_BUN.y        5
# 0        Min_Weight.x        1       Mean_Weight.y       14
# 8         Min_Urine.x       24        Mean_Urine.y        1
# 5      Min_NISysABP.x       15     Mean_NISysABP.y        3
# 20        Min_PaCO2.x       11        Mean_PaCO2.y       10
# 33      Min_Lactate.x        7      Mean_Lactate.y        8
# 7          Min_Temp.x        8         Mean_Temp.y        9
# 21         Min_PaO2.x       13         Mean_PaO2.y       12
# 26       Min_SysABP.x       29       Mean_SysABP.y       13
# 12         Min_HCO3.x       12         Mean_HCO3.y       17
# 4         Min_NIMAP.x        6        Mean_NIMAP.y       18
# 32    Min_Bilirubin.x       14    Mean_Bilirubin.y       15
# 17           Min_Na.x       22           Mean_Na.y       16
# 19           Min_pH.x        3           Mean_pH.y       22
# 10   Min_Creatinine.x       16   Mean_Creatinine.y       20
# 3     Min_NIDiasABP.x       19    Mean_NIDiasABP.y       19
# 28      Min_Albumin.x       18      Mean_Albumin.y       28
# 14           Min_Mg.x       25           Mean_Mg.y       21
# 31          Min_AST.x       20          Mean_AST.y       27
# 16            Min_K.x       23            Mean_K.y       23
# 24          Min_MAP.x       17          Mean_MAP.y       26
# 23         Min_FiO2.x       27         Mean_FiO2.y       25
# 30          Min_ALT.x       26          Mean_ALT.y       24
# 22      Min_DiasABP.x       28      Mean_DiasABP.y       29
# 29          Min_ALP.x       30          Mean_ALP.y       32
# 6      Min_RespRate.x       31     Mean_RespRate.y       31
# 36    Min_TroponinT.x       32    Mean_TroponinT.y       30
# 27         Min_SaO2.x       33         Mean_SaO2.y       33
# 35    Min_TroponinI.x       34    Mean_TroponinI.y       34
# 34  Min_Cholesterol.x       35  Mean_Cholesterol.y       35
# 25     Min_MechVent.x       36     Mean_MechVent.y       36
#
#               Feature  Ranking            Feature  Ranking  Row Sum
# 15    Max_Platelets.y        6    Min_Platelets.y        1       22
# 18          Max_WBC.y        1          Min_WBC.y        1       25
# 11      Max_Glucose.y        2      Min_Glucose.y        6       29
# 13          Max_GCT.y        1          Min_GCT.y        3       29
# 2            Max_HR.y        5           Min_HR.y        8       31
# 1           Max_GCS.y        4          Min_GCS.y        4       42
# 9           Max_BUN.y       10          Min_BUN.y        5       43
# 0        Max_Weight.y       11       Min_Weight.y        2       50
# 8         Max_Urine.y        3        Min_Urine.y       18       52
# 5      Max_NISysABP.y        7     Min_NISysABP.y       15       60
# 20        Max_PaCO2.y       15        Min_PaCO2.y       14       60
# 33      Max_Lactate.y       12      Min_Lactate.y        7       62
# 7          Max_Temp.y       19         Min_Temp.y        9       65
# 21         Max_PaO2.y        8         Min_PaO2.y       12       69
# 26       Max_SysABP.y        9       Min_SysABP.y       16       85
# 12         Max_HCO3.y       22         Min_HCO3.y       10       86
# 4         Max_NIMAP.y       13        Min_NIMAP.y       11       88
# 32    Max_Bilirubin.y       14    Min_Bilirubin.y       13       95
# 17           Max_Na.y       16           Min_Na.y       17      108
# 19           Max_pH.y       24           Min_pH.y       24      109
# 10   Max_Creatinine.y       17   Min_Creatinine.y       22      118
# 3     Max_NIDiasABP.y       18    Min_NIDiasABP.y       25      125
# 28      Max_Albumax.y       26      Min_Albumin.y       23      132
# 14           Max_Mg.y       21           Min_Mg.y       19      133
# 31          Max_AST.y       20          Min_AST.y       20      134
# 16            Max_K.y       23            Min_K.y       21      139
# 24          Max_MAP.y       28          Min_MAP.y       26      150
# 23         Max_FiO2.y       30         Min_FiO2.y       30      156
# 30          Max_ALT.y       27          Min_ALT.y       27      158
# 22      Max_DiasABP.y       25      Min_DiasABP.y       28      166
# 29          Max_ALP.y       29          Min_ALP.y       29      182
# 6      Max_RespRate.y       32     Min_RespRate.y       33      186
# 36    Max_TroponinT.y       31    Min_TroponinT.y       31      188
# 27         Max_SaO2.y       33         Min_SaO2.y       32      195
# 35    Max_TroponinI.y       34    Min_TroponinI.y       34      204
# 34  Max_Cholesterol.y       35  Min_Cholesterol.y       35      210
# 25     Max_MechVent.y       36     Min_MechVent.y       36      216

# %%
datasets = [gen,mean1,min1,max1,mean2,min2,max2,outcome]
new_df = pd.DataFrame(index=df.index)
for dataset in datasets:
    keep_vars = ["GCS", "HR", "Platelets", "Urine", "WBC", "BUN", "Temp", "Glucose", "PaO2", "PaCO2","SysABP","HCO3","Weight", "Lactate"]
    base_name = f"{dataset}new"
    keep_vars_lower = [v.lower() for v in keep_vars]
    
    filtered_cols = [
        col for col in df.columns
        if any(k in col.lower() for k in keep_vars_lower)
    ]
    
    new_df = pd.concat([new_df, df[filtered_cols]], axis=1)

# %%
new_df.columns
# Out:
# Index(['Mean_Weight.x', 'Mean_GCS.x', 'Mean_HR.x', 'Mean_NISysABP.x',
#        'Mean_Temp.x', 'Mean_Urine.x', 'Mean_BUN.x', 'Mean_Glucose.x',
#        'Mean_HCO3.x', 'Mean_Platelets.x',
#        ...
#        'Max_Urine.y', 'Max_BUN.y', 'Max_Glucose.y', 'Max_HCO3.y',
#        'Max_Platelets.y', 'Max_WBC.y', 'Max_PaCO2.y', 'Max_PaO2.y',
#        'Max_SysABP.y', 'Max_Lactate.y'],
#       dtype='object', length=720)

# %%
new_df = new_df.loc[:, ~new_df.columns.duplicated()]

# %%
df_meandif = pd.DataFrame(index=new_df.index)  # start new df

for col in new_df.columns:
    if col.startswith("Mean_") and col.endswith(".x"):
        base_name = col[:-2]  # remove ".x"
        col_x = base_name + ".x"
        col_y = base_name + ".y"

        if col_y in new_df.columns:
            # Mean across x and y
            df_meandif[base_name + "_mean_xy"] = (new_df[col_x] + new_df[col_y]) / 2.0

            # Difference (y - x)
            df_meandif[base_name + "_diff"] = new_df[col_y] - new_df[col_x]

# %%
df_meandif2 = pd.DataFrame(index=df.index)  # start new df

for col in df.columns:
    if col.startswith("Mean_") and col.endswith(".x"):
        base_name = col[:-2]  # remove ".x"
        col_x = base_name + ".x"
        col_y = base_name + ".y"

        if col_y in df.columns:
            # Mean across x and y
            df_meandif2[base_name + "_mean_xy"] = (df[col_x] + df[col_y]) / 2.0

            # Difference (y - x)
            df_meandif2[base_name + "_diff"] = df[col_y] - df[col_x]

# %%
df_meandif
# Out:
#       Mean_Weight_mean_xy  Mean_Weight_diff  Mean_GCS_mean_xy  Mean_GCS_diff  \
# 0               84.600000          0.000000         14.944444       0.111111
# 1               83.181098          0.253925         15.000000       0.000000
# 2              114.000000          0.000000          8.611111       0.555556
# 3               48.400000          0.000000         11.425000      -3.650000
# 4               60.700000          0.000000         15.000000       0.000000
# ...                   ...               ...               ...            ...
# 1469            64.000000          0.000000         10.996032      -0.436508
# 1470            53.000000          0.000000         13.833333       1.666667
# 1471            75.000000          0.000000          9.954545       0.090909
# 1472            87.000000          0.000000         12.791667       3.916667
# 1473            87.400000          0.000000          5.366667      -2.066667
#
#       Mean_HR_mean_xy  Mean_HR_diff  Mean_NISysABP_mean_xy  \
# 0           70.585714     -4.771429             121.268382
# 1           74.760000     -9.520000             133.490260
# 2           88.099091     13.561818             105.000000
# 3           71.733232    -12.783537             104.059524
# 4          127.327652     -4.071970             124.537879
# ...               ...           ...                    ...
# 1469        86.047101     -0.427536             133.590278
# 1470        81.693403     -7.647676             122.237288
# 4           -2.162121             124.537879           -2.742424
# ...               ...                    ...                 ...
# 1469         4.283333             133.590278           10.597222
# 1470         3.957805             122.237288            1.525424
# 1471         0.596576             117.148740            1.388940
# 1472        10.234000             114.050000           15.300000
# 1473         0.596576             117.148740            1.388940
#
#       Mean_RespRate_mean_xy  Mean_RespRate_diff  Mean_Temp_mean_xy  \
# 0                 15.409091           -0.818182          36.223810
# 1                 19.142609           -1.154783          36.820000
# 2                 19.657353           -0.018125          37.458333
# 3                 19.657353           -0.018125          37.056667
# 4                 34.954545           -0.909091          36.900000
# ...                     ...                 ...                ...
# 1469              19.560386           -0.009662          36.912500
# 1470              19.657353           -0.018125          36.941667
# 1471              19.657353           -0.018125          37.031250
# 1472              19.657353           -0.018125          36.914286
# 1473              19.657353           -0.018125          38.269643
#
#       Mean_Temp_diff  Mean_Urine_mean_xy  Mean_Urine_diff  Mean_BUN_mean_xy  \
# 0           0.019048          545.833333       158.333333             15.75
# 1          -0.360000           62.261111         4.922222             35.00
# 2           0.716667          153.194444      -168.611111             16.75
# 3          -0.153333           43.605263       -15.210526             63.50
# 4          -0.280000          241.666667        16.666667             22.00
# ...              ...                 ...              ...               ...
# 1469       -0.175000          137.766544        42.591912             13.25
# 1470       -0.450000           69.344156         4.402597             63.00
# 1471        0.437500          137.450758        34.265152             12.25
# 1472        0.542857           51.570856       -12.505348             16.00
# 1473       -1.089286           14.916667        19.166667             97.50
#
#       Mean_BUN_diff  Mean_Creatinine_mean_xy  Mean_Creatinine_diff  \
# 0             -11.5                 0.750000             -0.100000
# 1             -20.0                 1.000000              0.000000
# 2              -0.5                 0.975000             -0.350000
# 3             -11.0                 0.666667             -0.133333
# 4               2.0                 0.700000              0.000000
# ...             ...                      ...                   ...
# 1469            1.5                 1.075000             -0.150000
# 1470           12.0                 2.200000              0.000000
# 1471            5.5                 0.475000              0.050000
# 1472            4.0                 0.900000              0.200000
# 1473           33.0                10.333333              2.733333
#
#       Mean_Glucose_mean_xy  Mean_Glucose_diff  Mean_HCO3_mean_xy  \
# 0               117.250000          -0.500000          27.750000
# 1               102.500000         -21.000000          19.000000
# 2               191.750000         -77.500000          19.750000
# 3               124.916667         -12.833333          13.416667
# 4               112.500000          -1.000000          23.000000
# ...                    ...                ...                ...
# 1469             96.500000          -1.000000          22.250000
# 1470            104.000000          -4.000000          19.000000
# 1471            118.000000         -14.000000          26.000000
# 1472            117.250000         -22.500000          21.500000
# 1473            125.666667         -15.333333          24.833333
#
#       Mean_HCO3_diff  Mean_GCT_mean_xy  Mean_GCT_diff  Mean_Mg_mean_xy  \
# 0           0.500000         37.085000      -1.670000            2.000
# 1           2.000000         29.550000       3.366667            1.550
# 2           1.500000         37.225000      -3.950000            1.950
# 3          -1.833333         33.175000      -0.350000            2.375
# 4           4.000000         28.300000       0.000000            1.650
# ...              ...               ...            ...              ...
# 1469        1.500000         34.375000       3.850000            1.825
# 1470        2.000000         31.750000      -0.100000            1.800
# 1471        2.000000         29.287500      -0.375000            1.850
# 1472        1.000000         29.075000      -0.950000            1.600
# 1473       -7.666667         28.033333      -1.866667            2.925
#
#       Mean_Mg_diff  Mean_Platelets_mean_xy  Mean_Platelets_diff  \
# 0            -0.20              318.500000           -69.000000
# 1             0.10              103.000000           -12.000000
# 2             0.50              210.750000           -73.500000
# 3            -1.55               97.750000             8.500000
# 4             0.10              696.000000             0.000000
# ...            ...                     ...                  ...
# 1469         -0.05              303.500000            29.000000
# 1470          0.40              164.000000            -8.000000
# 1471          0.10              163.000000            84.000000
# 1472          0.70              208.000000            20.000000
# 1473          0.35              321.833333           -15.666667
#
#       Mean_K_mean_xy  Mean_K_diff  Mean_Na_mean_xy  Mean_Na_diff  \
# 0           3.950000    -0.300000           138.75          -3.5
# 1           4.258333    -0.616667           139.50          -1.0
# 2           4.150000    -0.833333           137.75          -2.5
# 3           4.408333     0.283333           139.25          -3.5
# 4           4.200000     0.600000           139.00           0.0
# ...              ...          ...              ...           ...
# 1469        4.000000    -0.400000           133.75           4.5
# 1470        4.500000     0.400000           136.50          -1.0
# 1471        3.800000    -0.200000           142.25           1.5
# 1472        3.766667     0.266667           137.00          -2.0
# 1473        4.766667     0.466667           144.00           0.0
#
#       Mean_WBC_mean_xy  Mean_WBC_diff  Mean_pH_mean_xy  Mean_pH_diff  \
# 0             9.025000      -2.250000         7.503998     -0.074745
# 1             4.300000       1.000000         7.503998     -0.074745
# 2            16.100000      -6.200000         7.399583      0.085833
# 3            20.875000       5.250000         7.282500      0.085000
# 4            15.200000       0.000000         7.503998     -0.074745
# ...                ...            ...              ...           ...
# 1469         10.150000       2.500000         7.503998     -0.074745
# 1470         15.900000      -9.800000         7.503998     -0.074745
# 1471          7.975000       0.050000         7.443333      0.060000
# 1472         14.500000       6.000000         7.387000      0.026000
# 1473         12.516667      -2.033333         7.387500     -0.095000
#
#       Mean_PaCO2_mean_xy  Mean_PaCO2_diff  Mean_PaO2_mean_xy  Mean_PaO2_diff  \
# 0              40.267430        -0.468259         142.896559      -30.103035
# 1              40.267430        -0.468259         142.896559      -30.103035
# 2              35.541667        -5.583333         107.125000       40.250000
# 3              29.777778        -7.555556         126.638889      -37.611111
# 4              40.267430        -0.468259         142.896559      -30.103035
# ...                  ...              ...                ...             ...
# 1469           40.267430        -0.468259         142.896559      -30.103035
# 1470           40.267430        -0.468259         142.896559      -30.103035
# 1471           40.000000        -4.333333         138.250000      -63.500000
# 1472           40.600000         0.800000         128.750000      -58.500000
# 1473           44.125000        -0.250000         181.000000       18.000000
#
#       Mean_DiasABP_mean_xy  Mean_DiasABP_diff  Mean_FiO2_mean_xy  \
# 0                59.528228           0.436629           0.548367
# 1                59.528228           0.436629           0.548367
# 2                72.990000          11.380000           0.471429
# 3                39.097887         -10.126808           0.560714
# 4                59.528228           0.436629           0.548367
# ...                    ...                ...                ...
# 1469             59.528228           0.436629           0.548367
# 1470             59.528228           0.436629           0.548367
# 1471             70.486520           4.443627           0.414286
# 1472             68.648810           5.630952           0.442857
# 1473             93.095238           4.476190           0.531250
#
#       Mean_FiO2_diff  Mean_MAP_mean_xy  Mean_MAP_diff  Mean_MechVent_mean_xy  \
# 0          -0.046936         81.205517       0.834636                    1.0
# 1          -0.046936         81.205517       0.834636                    1.0
# 2          -0.057143         87.805000      15.910000                    1.0
# 3          -0.178571         64.566185     -12.028921                    1.0
# 4          -0.046936         81.205517       0.834636                    1.0
# ...              ...               ...            ...                    ...
# 1469       -0.046936         81.205517       0.834636                    1.0
# 1470       -0.046936         81.205517       0.834636                    1.0
# 1471       -0.028571         86.883578       5.649510                    1.0
# 1472        0.000000         86.440476      11.047619                    1.0
# 1473       -0.062500        116.041667       8.083333                    1.0
#
#       Mean_MechVent_diff  Mean_SysABP_mean_xy  Mean_SysABP_diff  \
# 0                      0           118.720769          3.050009
# 1                      0           118.720769          3.050009
# 2                      0           114.450000         22.300000
# 3                      0           125.459956         -5.402670
# 4                      0           118.720769          3.050009
# ...                  ...                  ...               ...
# 1469                   0           118.720769          3.050009
# 1470                   0           118.720769          3.050009
# 1471                   0           117.888480          7.306373
# 1472                   0           116.625000         15.750000
# 1473                   0           166.848214          6.053571
#
#       Mean_SaO2_mean_xy  Mean_SaO2_diff  Mean_Albumin_mean_xy  \
# 0             96.565436       -0.206627              4.400000
# 1             96.565436       -0.206627              3.300000
# 2             97.166667        1.666667              2.969733
# 3             96.250000        1.500000              1.900000
# 4             96.565436       -0.206627              2.969733
# ...                 ...             ...                   ...
# 1469          96.565436       -0.206627              3.600000
# 1470          96.565436       -0.206627              2.600000
# 1471          98.000000        0.000000              2.969733
# 1472          96.565436       -0.206627              2.969733
# 1473          96.565436       -0.206627              3.100000
#
#       Mean_Albumin_diff  Mean_ALP_mean_xy  Mean_ALP_diff  Mean_ALT_mean_xy  \
# 0              0.000000        105.000000       0.000000         12.000000
# 1              0.000000        104.674194      -0.993583        171.898699
# 2             -0.028164        101.000000       0.000000         52.500000
# 3              0.000000         47.000000       0.000000         46.000000
# 4             -0.028164        104.674194      -0.993583        171.898699
# ...                 ...               ...            ...               ...
# 1469           0.000000        104.674194      -0.993583        171.898699
# 1470           0.000000        173.500000     -37.000000         31.500000
# 1471          -0.028164        104.674194      -0.993583        171.898699
# 1472          -0.028164        104.674194      -0.993583        171.898699
# 1473           0.000000        166.250000     -16.500000       1856.500000
#
#       Mean_ALT_diff  Mean_AST_mean_xy  Mean_AST_diff  Mean_Bilirubin_mean_xy  \
# 0          0.000000         15.000000        0.00000                0.200000
# 1         13.577892        237.504928       -2.04085                1.905911
# 2          0.000000        104.500000        0.00000                0.400000
# 3          0.000000         82.000000        0.00000                0.300000
# 4         13.577892        237.504928       -2.04085                1.905911
# ...             ...               ...            ...                     ...
# 1469      13.577892        237.504928       -2.04085                1.905911
# 1470      -7.000000         36.000000       -2.00000                1.000000
# 1471      13.577892        237.504928       -2.04085                1.905911
# 1472      13.577892        237.504928       -2.04085                1.905911
# 1473    -687.000000       1583.250000     -612.50000                0.700000
#
#       Mean_Bilirubin_diff  Mean_Lactate_mean_xy  Mean_Lactate_diff  \
# 0                0.000000              2.250612          -0.326386
# 1                0.047878              2.250612          -0.326386
# 2                0.000000              2.250612          -0.326386
# 3                0.000000              1.775000           0.550000
# 4                0.047878              2.250612          -0.326386
# ...                   ...                   ...                ...
# 1469             0.047878              2.250612          -0.326386
# 1470            -0.200000              2.250612          -0.326386
# 1471             0.047878              2.250612          -0.326386
# 1472             0.047878              1.787500          -1.375000
# 1473            -0.200000              1.900000           0.000000
#
#       Mean_Cholesterol_mean_xy  Mean_Cholesterol_diff  Mean_TroponinI_mean_xy  \
# 0                   156.648026               0.157895                6.882073
# 1                   156.648026               0.157895                6.882073
# 2                   212.000000               0.000000                1.300000
# 3                   156.648026               0.157895                3.300000
# 4                   156.648026               0.157895                6.882073
# ...                        ...                    ...                     ...
# 1469                156.648026               0.157895                6.882073
# 1470                156.648026               0.157895                6.882073
# 1471                156.648026               0.157895                6.882073
# 1472                156.648026               0.157895                6.882073
# 1473                156.648026               0.157895                6.882073
#
#       Mean_TroponinI_diff  Mean_TroponinT_mean_xy  Mean_TroponinT_diff
# 0               -0.579593                1.062008             -0.07262
# 1               -0.579593                1.062008             -0.07262
# 2                0.000000                1.062008             -0.07262
# 3                0.000000                1.062008             -0.07262
# 4               -0.579593                1.062008             -0.07262
# ...                   ...                     ...                  ...
# 1469            -0.579593                1.062008             -0.07262
# 1470            -0.579593                1.062008             -0.07262
# 1471            -0.579593                1.062008             -0.07262
# 1472            -0.579593                1.062008             -0.07262
# 1473            -0.579593                1.062008             -0.07262
#
# [1472 rows x 306 columns]

# %%
all_g = df_combined2.drop(["In.hospital_death", "RecordID"], axis = 1)

# %%
all_r = do_rfe(all_g, y, 2)

# %%
all_r = all_r.sort_values(by = "Ranking",ascending = True)

# %%
all_r
# Out:
#                 Feature  Ranking
# 8             Mean_HR.x        1
# 125        Mean_Urine.y        1
# 118          Mean_GCS.y        2
# 122     Mean_NISysABP.y        3
# 232    Mean_GCS_mean_xy        4
# ..                  ...      ...
# 31      Mean_MechVent.x      299
# 68       Min_MechVent.x      300
# 281  Mean_MechVent_diff      301
# 216      Max_MechVent.y      302
# 105      Max_MechVent.x      303
#
# [304 rows x 2 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
all_r
# Out:
#                       Feature  Ranking
# 8                   Mean_HR.x        1
# 125              Mean_Urine.y        1
# 118                Mean_GCS.y        2
# 122           Mean_NISysABP.y        3
# 232          Mean_GCS_mean_xy        4
# 209                 Max_WBC.y        5
# 126                Mean_BUN.y        6
# 82                   Max_HR.x        7
# 233             Mean_GCS_diff        8
# 261       Mean_Platelets_diff        9
# 272         Mean_PaO2_mean_xy       10
# 187             Min_Lactate.y       11
# 204                 Max_GCT.y       12
# 128            Mean_Glucose.y       13
# 154              Min_Weight.y       14
# 196            Max_NISysABP.y       15
# 246        Mean_Urine_mean_xy       16
# 172                 Min_WBC.y       17
# 192                 Max_GCS.y       18
# 18                Mean_HCO3.x       19
# 282       Mean_SysABP_mean_xy       20
# 234           Mean_HR_mean_xy       21
# 270        Mean_PaCO2_mean_xy       22
# 186           Min_Bilirubin.y       23
# 7                  Mean_GCS.x       24
# 101                Max_PaO2.x       25
# 257             Mean_GCT_diff       26
# 135                Mean_WBC.y       27
# 254         Mean_HCO3_mean_xy       28
# 252      Mean_Glucose_mean_xy       29
# 245            Mean_Temp_diff       30
# 296      Mean_Lactate_mean_xy       31
# 200                 Max_BUN.y       32
# 199               Max_Urine.y       33
# 62                   Min_pH.x       34
# 235              Mean_HR_diff       35
# 193                  Max_HR.y       36
# 217              Max_SysABP.y       37
# 26               Mean_PaCO2.x       38
# 121              Mean_NIMAP.y       39
# 155                 Min_GCS.y       40
# 93                  Max_GCT.x       41
# 6               Mean_Weight.x       42
# 260    Mean_Platelets_mean_xy       43
# 124               Mean_Temp.y       44
# 29                Mean_FiO2.x       45
# 27                Mean_PaO2.x       46
# 95            Max_Platelets.x       47
# 13                Mean_Temp.x       48
# 195               Max_NIMAP.y       49
# 202             Max_Glucose.y       50
# 258           Mean_Mg_mean_xy       51
# 134                 Mean_Na.y       52
# 229                      SOFA       53
# 50                 Min_Temp.x       54
# 267             Mean_WBC_diff       55
# 130                Mean_GCT.y       56
# 266          Mean_WBC_mean_xy       57
# 294    Mean_Bilirubin_mean_xy       58
# 11            Mean_NISysABP.x       59
# 264           Mean_Na_mean_xy       60
# 138               Mean_PaO2.y       61
# 119                 Mean_HR.y       62
# 250   Mean_Creatinine_mean_xy       63
# 32              Mean_SysABP.x       64
# 248          Mean_BUN_mean_xy       65
# 137              Mean_PaCO2.y       66
# 276         Mean_FiO2_mean_xy       67
# 17             Mean_Glucose.x       68
# 15                 Mean_BUN.x       69
# 277            Mean_FiO2_diff       70
# 43               Min_Weight.x       71
# 45                   Min_HR.x       72
# 224             Max_Lactate.y       73
# 230       Mean_Weight_mean_xy       74
# 76              Min_Lactate.x       75
# 165             Min_Glucose.y       76
# 240     Mean_NISysABP_mean_xy       77
# 253         Mean_Glucose_diff       78
# 58            Min_Platelets.x       79
# 239           Mean_NIMAP_diff       80
# 149          Mean_Bilirubin.y       81
# 56                  Min_GCT.x       82
# 129               Mean_HCO3.y       83
# 14               Mean_Urine.x       84
# 0                         Age       85
# 283          Mean_SysABP_diff       86
# 163                 Min_BUN.y       87
# 249             Mean_BUN_diff       88
# 22                   Mean_K.x       89
# 237       Mean_NIDiasABP_diff       90
# 100               Max_PaCO2.x       91
# 127         Mean_Creatinine.y       92
# 212                Max_PaO2.y       93
# 117             Mean_Weight.y       94
# 156                  Min_HR.y       95
# 247           Mean_Urine_diff       96
# 271           Mean_PaCO2_diff       97
# 292          Mean_AST_mean_xy       98
# 265              Mean_Na_diff       99
# 223           Max_Bilirubin.y      100
# 158               Min_NIMAP.y      101
# 133                  Mean_K.y      102
# 143             Mean_SysABP.y      103
# 167                 Min_GCT.y      104
# 19                 Mean_GCT.x      105
# 64                 Min_PaO2.x      106
# 244         Mean_Temp_mean_xy      107
# 241        Mean_NISysABP_diff      108
# 273            Mean_PaO2_diff      109
# 131                 Mean_Mg.y      110
# 194           Max_NIDiasABP.y      111
# 169           Min_Platelets.y      112
# 61                  Min_WBC.x      113
# 150            Mean_Lactate.y      114
# 161                Min_Temp.y      115
# 140               Mean_FiO2.y      116
# 87                 Max_Temp.x      117
# 166                Min_HCO3.y      118
# 297         Mean_Lactate_diff      119
# 259              Mean_Mg_diff      120
# 290          Mean_ALT_mean_xy      121
# 89                  Max_BUN.x      122
# 34             Mean_Albumin.x      123
# 24                 Mean_WBC.x      124
# 55                 Min_HCO3.x      125
# 88                Max_Urine.x      126
# 25                  Mean_pH.x      127
# 81                  Max_GCS.x      128
# 120          Mean_NIDiasABP.y      129
# 191              Max_Weight.y      130
# 175                Min_PaO2.y      131
# 38           Mean_Bilirubin.x      132
# 206           Max_Platelets.y      133
# 136                 Mean_pH.y      134
# 91              Max_Glucose.x      135
# 98                  Max_WBC.x      136
# 21           Mean_Platelets.x      137
# 164          Min_Creatinine.y      138
# 106              Max_SysABP.x      139
# 174               Min_PaCO2.y      140
# 147                Mean_ALT.y      141
# 170                   Min_K.y      142
# 9            Mean_NIDiasABP.x      143
# 132          Mean_Platelets.y      144
# 46            Min_NIDiasABP.x      145
# 275         Mean_DiasABP_diff      146
# 251      Mean_Creatinine_diff      147
# 238        Mean_NIMAP_mean_xy      148
# 180              Min_SysABP.y      149
# 80               Max_Weight.x      150
# 231          Mean_Weight_diff      151
# 92                 Max_HCO3.x      152
# 108             Max_Albumax.x      153
# 97                   Max_Na.x      154
# 255            Mean_HCO3_diff      155
# 213             Max_DiasABP.y      156
# 85             Max_NISysABP.x      157
# 263               Mean_K_diff      158
# 23                  Mean_Na.x      159
# 159            Min_NISysABP.y      160
# 20                  Mean_Mg.x      161
# 269              Mean_pH_diff      162
# 39             Mean_Lactate.x      163
# 279             Mean_MAP_diff      164
# 47                Min_NIMAP.x      165
# 83            Max_NIDiasABP.x      166
# 256          Mean_GCT_mean_xy      167
# 63                Min_PaCO2.x      168
# 262            Mean_K_mean_xy      169
# 268           Mean_pH_mean_xy      170
# 10               Mean_NIMAP.x      171
# 182             Min_Albumin.y      172
# 52                  Min_BUN.x      173
# 211               Max_PaCO2.y      174
# 96                    Max_K.x      175
# 54              Min_Glucose.x      176
# 173                  Min_pH.y      177
# 16          Mean_Creatinine.x      178
# 236    Mean_NIDiasABP_mean_xy      179
# 278          Mean_MAP_mean_xy      180
# 35                 Mean_ALP.x      181
# 201          Max_Creatinine.y      182
# 57                   Min_Mg.x      183
# 67                  Min_MAP.x      184
# 157           Min_NIDiasABP.y      185
# 205                  Max_Mg.y      186
# 162               Min_Urine.y      187
# 208                  Max_Na.y      188
# 198                Max_Temp.y      189
# 185                 Min_AST.y      190
# 28             Mean_DiasABP.x      191
# 53           Min_Creatinine.x      192
# 36                 Mean_ALT.x      193
# 60                   Min_Na.x      194
# 99                   Max_pH.x      195
# 210                  Max_pH.y      196
# 104                 Max_MAP.x      197
# 71              Min_Albumin.x      198
# 113             Max_Lactate.x      199
# 48             Min_NISysABP.x      200
# 42           Mean_TroponinT.x      201
# 168                  Min_Mg.y      202
# 295       Mean_Bilirubin_diff      203
# 207                   Max_K.y      204
# 171                  Min_Na.y      205
# 111                 Max_AST.x      206
# 84                Max_NIMAP.x      207
# 141                Mean_MAP.y      208
# 112           Max_Bilirubin.x      209
# 274      Mean_DiasABP_mean_xy      210
# 286      Mean_Albumin_mean_xy      211
# 12            Mean_RespRate.x      212
# 178                 Min_MAP.y      213
# 184                 Min_ALT.y      214
# 74                  Min_AST.x      215
# 102             Max_DiasABP.x      216
# 228                    SAPS.I      217
# 190           Min_TroponinT.y      218
# 2                      Height      219
# 65              Min_DiasABP.x      220
# 69               Min_SysABP.x      221
# 59                    Min_K.x      222
# 73                  Min_ALT.x      223
# 44                  Min_GCS.x      224
# 139            Mean_DiasABP.y      225
# 222                 Max_AST.y      226
# 51                Min_Urine.x      227
# 215                 Max_MAP.y      228
# 79            Min_TroponinT.x      229
# 293             Mean_AST_diff      230
# 203                Max_HCO3.y      231
# 146                Mean_ALP.y      232
# 90           Max_Creatinine.x      233
# 33                Mean_SaO2.x      234
# 219             Max_Albumax.y      235
# 72                  Min_ALP.x      236
# 37                 Mean_AST.x      237
# 288          Mean_ALP_mean_xy      238
# 289             Mean_ALP_diff      239
# 176             Min_DiasABP.y      240
# 123           Mean_RespRate.y      241
# 66                 Min_FiO2.x      242
# 94                   Max_Mg.x      243
# 145            Mean_Albumin.y      244
# 86             Max_RespRate.x      245
# 30                 Mean_MAP.x      246
# 75            Min_Bilirubin.x      247
# 177                Min_FiO2.y      248
# 242     Mean_RespRate_mean_xy      249
# 109                 Max_ALP.x      250
# 243        Mean_RespRate_diff      251
# 227           Max_TroponinT.y      252
# 285            Mean_SaO2_diff      253
# 153          Mean_TroponinT.y      254
# 284         Mean_SaO2_mean_xy      255
# 302    Mean_TroponinT_mean_xy      256
# 303       Mean_TroponinT_diff      257
# 144               Mean_SaO2.y      258
# 103                Max_FiO2.x      259
# 116           Max_TroponinT.x      260
# 160            Min_RespRate.y      261
# 110                 Max_ALT.x      262
# 214                Max_FiO2.y      263
# 220                 Max_ALP.y      264
# 197            Max_RespRate.y      265
# 221                 Max_ALT.y      266
# 183                 Min_ALP.y      267
# 148                Mean_AST.y      268
# 287         Mean_Albumin_diff      269
# 49             Min_RespRate.x      270
# 78            Min_TroponinI.x      271
# 291             Mean_ALT_diff      272
# 115           Max_TroponinI.x      273
# 70                 Min_SaO2.x      274
# 218                Max_SaO2.y      275
# 181                Min_SaO2.y      276
# 107                Max_SaO2.x      277
# 189           Min_TroponinI.y      278
# 226           Max_TroponinI.y      279
# 41           Mean_TroponinI.x      280
# 152          Mean_TroponinI.y      281
# 77          Min_Cholesterol.x      282
# 300    Mean_TroponinI_mean_xy      283
# 151        Mean_Cholesterol.y      284
# 114         Max_Cholesterol.x      285
# 188         Min_Cholesterol.y      286
# 298  Mean_Cholesterol_mean_xy      287
# 225         Max_Cholesterol.y      288
# 301       Mean_TroponinI_diff      289
# 3                    ICUType2      290
# 5                    ICUType4      291
# 4                    ICUType3      292
# 40         Mean_Cholesterol.x      293
# 299     Mean_Cholesterol_diff      294
# 1                      Gender      295
# 142           Mean_MechVent.y      296
# 280     Mean_MechVent_mean_xy      297
# 179            Min_MechVent.y      298
# 31            Mean_MechVent.x      299
# 68             Min_MechVent.x      300
# 281        Mean_MechVent_diff      301
# 216            Max_MechVent.y      302
# 105            Max_MechVent.x      303
